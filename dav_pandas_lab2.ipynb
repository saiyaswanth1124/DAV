# %% [markdown]
# if no index is passed then by default index will be range(n) where n is array length ie.[0,1,2,3..range(len(array))-1]

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data=np.array(['a','b','c','d'])
s=pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data=np.array(['a','b','c','d'])
s=pd.Series(data,index=[100,101,102,103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
import pandas as pd
import numpy as np
data={'a':0.,'b':1.,'c':2.}
s=pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
data={'a':0.,'b':1.,'c':2.}
s=pd.Series(data,index=['b','c','d','a'])
print(s)
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
s=pd.Series(5,index=[0,1,2,3])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
#retrieve the first element
print(s[0])
# Out:
# 1

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s[:3])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# retrieve data using label(index)

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s['a'])
# Out:
# 1

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s[['a','d']])
# Out:
# a    1
# d    4
# dtype: int64

# %%
s=pd.Series([1,2,3],index=(['a','b','c']),dtype=float)

print(s)
# Out:
# a    1.0
# b    2.0
# c    3.0
# dtype: float64

# %% [markdown]
# DataFrame

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data=[1,2,3,4,5]
df=pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data=[['alex',18],['bob',19],['siva',20]]
df=pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#    Name  Age
# 0  alex   18
# 1   bob   19
# 2  siva   20

# %%
data=[['alex',18],['bob',19],['siva',20]]
df=pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print(df)
# Out:
#    Name   Age
# 0  alex  18.0
# 1   bob  19.0
# 2  siva  20.0
# <ipython-input-16-d644f0e60e50>:2: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df=pd.DataFrame(data,columns=['Name','Age'],dtype=float)

# %% [markdown]
# creating a list of dictnory

# %%
import pandas as pd
data=[{'a':1,'b':2,},{'a':5,'b':10,'c':20}]
df=pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
data=[{'a':1,'b':2,},{'a':5,'b':10,'c':20}]
df=pd.DataFrame(data,index=['first','second'])
print(df)
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
data=[{'a':1,'b':2,},{'a':5,'b':10,'c':20}]
df1=pd.DataFrame(data,index=['first','second'],columns=['a','b'])
df2=pd.DataFrame(data,index=['first','second'],columns=['a','b1'])
print(df1)
print(df2)
# Out:
#         a   b
# first   1   2
# second  5  10
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %% [markdown]
# column addition

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print("adding a new columns by passing as series:")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
print("adding a new column the existing columns in dataframe:")
df['four']=df['one']+df['two']
print(df)
# Out:
# adding a new columns by passing as series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# adding a new column the existing columns in dataframe:
#    one  two  three  four
# a  1.0    1   10.0   2.0
# b  2.0    2   20.0   4.0
# c  3.0    3   30.0   6.0
# d  NaN    4    NaN   NaN

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d']),
   'three':pd.Series([10,20,30],index=['a','b','c'])}
df=pd.DataFrame(d)
print("our dataframe is:")
print(df)
# Out:
# our dataframe is:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN

# %%
print("deleting the first column by using the del function:")
del(df['one'])
print(df)
print("deleting the first column by using the pop function:")
df.pop('two')
print(df)
# Out:
# deleting the first column by using the del function:
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
# deleting the first column by using the pop function:
#    three
# a   10.0
# b   20.0
# c   30.0
# d    NaN

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df.loc[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df[2:4])
# Out:
#    one  two
# c  3.0    3
# d  NaN    4

# %%
df=pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df=df.append(df2)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
# <ipython-input-28-d31ad2479008>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2)

# %%
df=pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df=df.append(df2)
df=df.drop(0)#drop with label 0
print(df)
# Out:
#    a  b
# 1  3  4
# 1  7  8
# <ipython-input-29-15a0971ad069>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2)

# %% [markdown]
# ***loading the data set**

# %%
import pandas as pd
df=pd.read_csv("/content/heart1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-6d2518285ba1> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/content/heart1.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head()
# Out:
#    a  b
# 1  3  4
# 1  7  8

# %%
df.shape

# %%
df.tail()

# %%
df.info()

# %%
df.describe()
